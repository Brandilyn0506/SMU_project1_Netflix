# %%
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd
import seaborn as sns
import scipy.stats as st

# %%
filepath = "NetflixDF4.csv"

# %%
# Read and display with pandas
df = pd.read_csv(filepath)
df.head()
# Out:
#   show_id                 title  release_year   type rating        country  \
# 0      s1  Dick Johnson Is Dead          2020  Movie  PG-13  United States
# 1      s8               Sankofa          1993  Movie      R  United States
# 2     s10          The Starling          2021  Movie  PG-13  United States
# 3     s25                 Jeans          1998  Movie  PG-13          India
# 4     s28             Grown Ups          2010  Movie  PG-13  United States
#
#            genre  duration
# 0  Documentaries      90.0
# 1         Dramas     125.0
# 2       Comedies     104.0
# 3       Comedies     166.0
# 4       Comedies     103.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3558 entries, 0 to 3557
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       3558 non-null   object
#  1   title         3558 non-null   object
#  2   release_year  3558 non-null   int64
#  3   type          3558 non-null   object
#  4   rating        3558 non-null   object
#  5   country       3558 non-null   object
#  6   genre         3558 non-null   object
#  7   duration      3558 non-null   float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 222.5+ KB

# %%
df.describe()
# Out:
#        release_year     duration
# count   3558.000000  3558.000000
# mean    2011.912591   103.275998
# std       10.287760    26.900889
# min     1942.000000    41.000000
# 25%     2010.000000    88.000000
# 50%     2016.000000    99.000000
# 75%     2018.000000   119.000000
# max     2021.000000   312.000000

# %%
df.shape
# Out:
# (3558, 8)

# %%
#locate top genres
df2 = df.loc[(df['genre'] == 'Dramas') | (df['genre'] == 'Comedies' ) | (df['genre'] == 'Documentaries') | (df['genre'] == 'Action & Adventure')| (df['genre'] == 'Children & Family Movies')| (df['genre'] == 'Stand-Up Comedy')| (df['genre'] == 'Horror Movies')]
df2.head()
# Out:
#   show_id                 title  release_year   type rating        country  \
# 0      s1  Dick Johnson Is Dead          2020  Movie  PG-13  United States
# 1      s8               Sankofa          1993  Movie      R  United States
# 2     s10          The Starling          2021  Movie  PG-13  United States
# 3     s25                 Jeans          1998  Movie  PG-13          India
# 4     s28             Grown Ups          2010  Movie  PG-13  United States
#
#            genre  duration
# 0  Documentaries      90.0
# 1         Dramas     125.0
# 2       Comedies     104.0
# 3       Comedies     166.0
# 4       Comedies     103.0

# %%
#sort by longest movies
df3 = df2.sort_values('duration', ascending = False)
df3
# Out:
#      show_id                               title  release_year   type rating  \
# 1333   s4254          Black Mirror: Bandersnatch          2018  Movie      R
# 320    s1020                              Lagaan          2001  Movie     PG
# 1464   s4574                        Jodhaa Akbar          2008  Movie  PG-13
# 1036   s3228                        The Irishman          2019  Movie      R
# 871    s2732            Kabhi Khushi Kabhie Gham          2001  Movie  PG-13
# ...      ...                                 ...           ...    ...    ...
# 536    s1667                          Alien Xmas          2020  Movie     PG
# 1275   s4093  Kevin James: Sweat the Small Stuff          2001  Movie     PG
# 706    s2200                    The Speed Cubers          2020  Movie     PG
# 1930   s5796                   The White Helmets          2016  Movie     PG
# 2683   s7168                               Kalki          2017  Movie  PG-13
#
#              country                     genre  duration
# 1333   United States                    Dramas     312.0
# 320            India                    Dramas     224.0
# 1464           India        Action & Adventure     214.0
# 1036   United States                    Dramas     209.0
# 871            India                    Dramas     209.0
# ...              ...                       ...       ...
# 536    United States  Children & Family Movies      42.0
# 1275   United States           Stand-Up Comedy      42.0
# 706    United States             Documentaries      41.0
# 1930  United Kingdom             Documentaries      41.0
# 2683           India                    Dramas      41.0
#
# [3348 rows x 8 columns]

# %%
#sort by shortest movies
lowest = df2.sort_values('duration', ascending = True)
lowest
# Out:
#      show_id                       title  release_year   type rating  \
# 706    s2200            The Speed Cubers          2020  Movie     PG
# 2683   s7168                       Kalki          2017  Movie  PG-13
# 1930   s5796           The White Helmets          2016  Movie     PG
# 536    s1667                  Alien Xmas          2020  Movie     PG
# 592    s1854           Rooting for Roona          2020  Movie     PG
# ...      ...                         ...           ...    ...    ...
# 871    s2732    Kabhi Khushi Kabhie Gham          2001  Movie  PG-13
# 1036   s3228                The Irishman          2019  Movie      R
# 1464   s4574                Jodhaa Akbar          2008  Movie  PG-13
# 320    s1020                      Lagaan          2001  Movie     PG
# 1333   s4254  Black Mirror: Bandersnatch          2018  Movie      R
#
#              country                     genre  duration
# 706    United States             Documentaries      41.0
# 2683           India                    Dramas      41.0
# 1930  United Kingdom             Documentaries      41.0
# 536    United States  Children & Family Movies      42.0
# 592            India             Documentaries      42.0
# ...              ...                       ...       ...
# 871            India                    Dramas     209.0
# 1036   United States                    Dramas     209.0
# 1464           India        Action & Adventure     214.0
# 320            India                    Dramas     224.0
# 1333   United States                    Dramas     312.0
#
# [3348 rows x 8 columns]

# %%
#top 5 shortest movies
lowest_df = lowest.head()
lowest_df
# Out:
#      show_id              title  release_year   type rating         country  \
# 706    s2200   The Speed Cubers          2020  Movie     PG   United States
# 2683   s7168              Kalki          2017  Movie  PG-13           India
# 1930   s5796  The White Helmets          2016  Movie     PG  United Kingdom
# 536    s1667         Alien Xmas          2020  Movie     PG   United States
# 592    s1854  Rooting for Roona          2020  Movie     PG           India
#
#                          genre  duration
# 706              Documentaries      41.0
# 2683                    Dramas      41.0
# 1930             Documentaries      41.0
# 536   Children & Family Movies      42.0
# 592              Documentaries      42.0

# %%
#calculate average duration by country
df2.groupby("country").mean()
# Out:
#                 release_year    duration
# country
# India            2011.811644  126.493151
# United Kingdom   2013.947059   96.611765
# United States    2012.604597   94.167448

# %%
#create summary statistics table
df2.groupby("country")["duration"].agg(['mean','max','min','median','std','var'])
# Out:
#                       mean    max   min  median        std         var
# country
# India           126.493151  224.0  41.0   127.0  25.205599  635.322239
# United Kingdom   96.611765  208.0  41.0    97.0  23.877190  570.120215
# United States    94.167448  312.0  41.0    94.0  21.472312  461.060169

# %%
#create India only data
india = df2[df2["country"] == "India"]
india.head()
# Out:
#    show_id             title  release_year   type rating country  \
# 3      s25             Jeans          1998  Movie  PG-13   India
# 16    s106  Angamaly Diaries          2017  Movie  PG-13   India
# 18    s115            Anjaam          1994  Movie  PG-13   India
# 20    s117            Dhanak          2015  Movie     PG   India
# 22    s119           Gurgaon          2017  Movie  PG-13   India
#
#                  genre  duration
# 3             Comedies     166.0
# 16  Action & Adventure     128.0
# 18              Dramas     143.0
# 20            Comedies     114.0
# 22              Dramas     106.0

# %%
#create USA only dataframe
usa = df2[df2["country"] == "United States"]
usa.head()
# Out:
#   show_id                 title  release_year   type rating        country  \
# 0      s1  Dick Johnson Is Dead          2020  Movie  PG-13  United States
# 1      s8               Sankofa          1993  Movie      R  United States
# 2     s10          The Starling          2021  Movie  PG-13  United States
# 4     s28             Grown Ups          2010  Movie  PG-13  United States
# 5     s29            Dark Skies          2013  Movie  PG-13  United States
#
#            genre  duration
# 0  Documentaries      90.0
# 1         Dramas     125.0
# 2       Comedies     104.0
# 4       Comedies     103.0
# 5  Horror Movies      97.0

# %%
#create UK only dataframe
uk = df2[df2["country"] == "United Kingdom"]
uk.head()
# Out:
#    show_id                 title  release_year   type rating         country  \
# 13     s95             Show Dogs          2018  Movie     PG  United Kingdom
# 19    s116           Bright Star          2009  Movie     PG  United Kingdom
# 21    s118         Final Account          2021  Movie  PG-13  United Kingdom
# 40    s156             Labyrinth          1986  Movie     PG  United Kingdom
# 57    s178  The Guns of Navarone          1961  Movie  PG-13  United Kingdom
#
#                        genre  duration
# 13  Children & Family Movies      90.0
# 19                    Dramas     119.0
# 21             Documentaries      94.0
# 40        Action & Adventure     101.0
# 57        Action & Adventure     156.0

# %%
#sort by decending
us_df = usa.sort_values('duration',ascending=False)
us_df
# Out:
#      show_id                                              title  release_year  \
# 1333   s4254                         Black Mirror: Bandersnatch          2018
# 1036   s3228                                       The Irishman          2019
# 3294   s8328                                 The Gospel of Luke          2015
# 3538   s8765                                         Wyatt Earp          1994
# 801    s2544  Unbreakable Kimmy Schmidt: Kimmy vs. the Reverend          2020
# ...      ...                                                ...           ...
# 536    s1667                                         Alien Xmas          2020
# 2412   s6648                   Dream Big: Engineering Our World          2017
# 817    s2580                   Go! Go! Cory Carson: The Chrissy          2020
# 1275   s4093                 Kevin James: Sweat the Small Stuff          2001
# 706    s2200                                   The Speed Cubers          2020
#
#        type rating        country                     genre  duration
# 1333  Movie      R  United States                    Dramas     312.0
# 1036  Movie      R  United States                    Dramas     209.0
# 3294  Movie  PG-13  United States                    Dramas     205.0
# 3538  Movie  PG-13  United States        Action & Adventure     191.0
# 801   Movie  PG-13  United States                  Comedies     190.0
# ...     ...    ...            ...                       ...       ...
# 536   Movie     PG  United States  Children & Family Movies      42.0
# 2412  Movie      G  United States             Documentaries      42.0
# 817   Movie     PG  United States  Children & Family Movies      42.0
# 1275  Movie     PG  United States           Stand-Up Comedy      42.0
# 706   Movie     PG  United States             Documentaries      41.0
#
# [2132 rows x 8 columns]

# %%
#sort India df by desencing
india_df = india.sort_values('duration',ascending=False)
india_df
# Out:
#      show_id                                              title  release_year  \
# 320    s1020                                             Lagaan          2001
# 1464   s4574                                       Jodhaa Akbar          2008
# 871    s2732                           Kabhi Khushi Kabhie Gham          2001
# 684    s2127                               What's Your Raashee?          2009
# 870    s2731                             Kabhi Alvida Naa Kehna          2006
# ...      ...                                                ...           ...
# 3304   s8351  The Human Factor: The Untold Story of the Bomb...          2013
# 3368   s8476                                       The Rat Race          2010
# 499    s1543         Vir Das: Outside In - The Lockdown Special          2020
# 592    s1854                                  Rooting for Roona          2020
# 2683   s7168                                              Kalki          2017
#
#        type rating country               genre  duration
# 320   Movie     PG   India              Dramas     224.0
# 1464  Movie  PG-13   India  Action & Adventure     214.0
# 871   Movie  PG-13   India              Dramas     209.0
# 684   Movie     PG   India            Comedies     203.0
# 870   Movie  PG-13   India              Dramas     192.0
# ...     ...    ...     ...                 ...       ...
# 3304  Movie     PG   India       Documentaries      53.0
# 3368  Movie     PG   India       Documentaries      52.0
# 499   Movie      R   India     Stand-Up Comedy      50.0
# 592   Movie     PG   India       Documentaries      42.0
# 2683  Movie  PG-13   India              Dramas      41.0
#
# [876 rows x 8 columns]

# %%
#sort UK dataframe by decending
uk_df=uk.sort_values('duration', ascending=False)
uk_df
# Out:
#      show_id                                title  release_year   type rating  \
# 833    s2633         No Direction Home: Bob Dylan          2005  Movie      R
# 2139   s6145                       American Honey          2016  Movie      R
# 3293   s8327                   The Gospel of John          2014  Movie  PG-13
# 682    s2121                       Les Misérables          2012  Movie  PG-13
# 1386   s4432                 Dhan Dhana Dhan Goal          2007  Movie  PG-13
# ...      ...                                  ...           ...    ...    ...
# 2577   s6979                    Hitler's Olympics          2016  Movie     PG
# 1804   s5467  The Mitfords: A Tale of Two Sisters          2017  Movie     PG
# 1798   s5452        Jackie: A Tale of Two Sisters          2017  Movie     PG
# 1795   s5449        Amelia: A Tale of Two Sisters          2017  Movie     PG
# 1930   s5796                    The White Helmets          2016  Movie     PG
#
#              country          genre  duration
# 833   United Kingdom  Documentaries     208.0
# 2139  United Kingdom         Dramas     163.0
# 3293  United Kingdom         Dramas     161.0
# 682   United Kingdom         Dramas     158.0
# 1386  United Kingdom         Dramas     157.0
# ...              ...            ...       ...
# 2577  United Kingdom  Documentaries      44.0
# 1804  United Kingdom  Documentaries      44.0
# 1798  United Kingdom  Documentaries      44.0
# 1795  United Kingdom  Documentaries      44.0
# 1930  United Kingdom  Documentaries      41.0
#
# [340 rows x 8 columns]

# %%
#obtain durations
durations_usa = usa['duration']
durations_usa
# Out:
# 0        90.0
# 1       125.0
# 2       104.0
# 4       103.0
# 5        97.0
#         ...
# 3549    113.0
# 3550     94.0
# 3551     88.0
# 3555     88.0
# 3556     88.0
# Name: duration, Length: 2132, dtype: float64

# %%
# Demonstrate calculating measures of central tendency
usa_mean = np.mean(durations_usa)
print(f"The mean duration of Movies in the USA is {usa_mean}")

usa_median= np.median(durations_usa)
print(f"The median duration of Movies in the USA is {usa_median}")

usa_mode = st.mode(durations_usa)
print(f"The mode duration of Movies in the USA is {usa_mode}")
# Out:
# The mean duration of Movies in the USA is 94.16744840525328
# The median duration of Movies in the USA is 94.0
# The mode duration of Movies in the USA is ModeResult(mode=array([90.]), count=array([74]))

# %%
#obtain UK durations
durations_uk = uk['duration']
durations_uk
# Out:
# 13       90.0
# 19      119.0
# 21       94.0
# 40      101.0
# 57      156.0
#         ...
# 3516     75.0
# 3520     91.0
# 3523     50.0
# 3527    105.0
# 3547     87.0
# Name: duration, Length: 340, dtype: float64

# %%
# Demonstrate calculating measures of central tendency
uk_mean = np.mean(durations_uk)
print(f"The mean duration of Movies in the UK is {uk_mean}")

uk_median= np.median(durations_uk)
print(f"The median duration of Movies in the UK is {uk_median}")

uk_mode = st.mode(durations_uk)
print(f"The mode duration of Movies in the UK is {uk_mode}")
# Out:
# The mean duration of Movies in the UK is 96.61176470588235
# The median duration of Movies in the UK is 97.0
# The mode duration of Movies in the UK is ModeResult(mode=array([90.]), count=array([12]))

# %%
#Obtain durations for India
durations_india = india['duration']
durations_india
# Out:
# 3       166.0
# 16      128.0
# 18      143.0
# 20      114.0
# 22      106.0
#         ...
# 3544    147.0
# 3545    151.0
# 3552    131.0
# 3553    120.0
# 3557    111.0
# Name: duration, Length: 876, dtype: float64

# %%
# Demonstrate calculating measures of central tendency
india_mean = np.mean(durations_india)
print(f"The mean duration of Movies in the India is {india_mean}")

india_median= np.median(durations_india)
print(f"The median duration of Movies in the India is {india_median}")

india_mode = st.mode(durations_india)
print(f"The mode duration of Movies in the India is {india_mode}")
# Out:
# The mean duration of Movies in the India is 126.4931506849315
# The median duration of Movies in the India is 127.0
# The mode duration of Movies in the India is ModeResult(mode=array([127.]), count=array([21]))

# %%
#count genres
df2.value_counts("genre")
# Out:
# genre
# Dramas                      924
# Comedies                    678
# Documentaries               515
# Action & Adventure          503
# Children & Family Movies    327
# Stand-Up Comedy             231
# Horror Movies               170
# dtype: int64

# %%
#Create USA Histogram
plt.figure(figsize=(10,5))
plt.hist(durations_usa, bins=20, color = "#E50914")
plt.title("USA Durations Histogram", fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.xlabel('Durations (min)', fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.ylabel('Counts',fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.show()

# %%
#USA Histogram with KDE
plt.figure(figsize=(10,5))
sns.histplot(data= usa, x="duration", kde=True, bins=20, color = "#E50914")
plt.title("USA Durations Histogram with KDE", fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.xlabel('Durations (min)', fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.ylabel('Counts',fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.savefig("usa_kde.png")
plt.show()

# %%
#Contain Normal Test
st.normaltest(usa.duration)
# Out:
# NormaltestResult(statistic=480.78057888079087, pvalue=3.9794567857123466e-105)

# %%
#UK Histogram
plt.figure(figsize=(10,5))
plt.hist(durations_uk, bins=20, color = "grey")
plt.title("UK Durations Histogram", fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.xlabel('Durations (min)', fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.ylabel('Counts',fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.show()

# %%
#UK Histogram with KDE
plt.figure(figsize=(10,5))
sns.histplot(data=uk, x="duration", kde=True, bins=20, color = "grey")
plt.title("UK Durations Histogram with KDE", fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.xlabel('Durations (min)', fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.ylabel('Counts',fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.savefig("uk_kde.png")
plt.show()

# %%
#Conduct Normal Test
st.normaltest(uk.duration)
# Out:
# NormaltestResult(statistic=13.476484263720076, pvalue=0.0011847279226933865)

# %%
#India Histogram
plt.figure(figsize=(10,5))
plt.hist(durations_india, bins=20, color = "black")
plt.title("India Durations Histogram", fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.xlabel('Durations (min)', fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.ylabel('Counts',fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.show()

# %%
#India Histogram with KDE
plt.figure(figsize=(10,5))
sns.histplot(data=india, x="duration", kde=True, bins=20, color = "black")
plt.title("India Durations Histogram with KDE", fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.xlabel('Durations (min)', fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.ylabel('Counts',fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.savefig("india_kde.png")
plt.show()

# %%
#Conduct Normal Test
st.normaltest(india.duration)
# Out:
# NormaltestResult(statistic=7.50447633423336, pvalue=0.023465168071458535)

# %%
#Create Violin Plot
import seaborn as sns
plt.figure(figsize=(15,8))
sns.set_theme(style="whitegrid")
ax = sns.violinplot(x="country", y="duration", data=df2,palette="binary")
plt.title("Countries by Duration", fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.xlabel('Country', fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.savefig("countries_violin2.png")
plt.ylabel('Durations (min)',fontname = "Verdana", fontsize=14,fontweight = 'bold')
# Out:
# Text(103.125, 0.5, 'Durations (min)')

# %%
#Box Plot Duration of Countires
plt.figure(figsize=(10,10))
plt.boxplot(df2.duration, showmeans=True)
plt.title("Durations of Countries", fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.ylabel('Duration (min)',fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.savefig("countries_box.png")
plt.show()

# %%
#Box Plot USA Durations
plt.figure(figsize=(10,10))
plt.boxplot(usa.duration, showmeans=True)
plt.title("USA Movie Duration", fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.ylabel('Duration (min)',fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.savefig("usa_box.png")
plt.show()

# %%
#Box Plot UK Durations
plt.figure(figsize=(10,10))
plt.boxplot(uk.duration, showmeans=True)
plt.title("UK Movie Duration", fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.ylabel('Duration (min)',fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.savefig("uk_box.png")
plt.show()

# %%
#Box Plot India Movie Durations
plt.figure(figsize=(10,10))
plt.boxplot(india.duration, showmeans=True)
plt.title("India Movie Duration", fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.ylabel('Duration (min)',fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.savefig("india_box.png")
plt.show()

# %%
#Side by Side Bar Chart
sns.catplot(x = 'country', y='duration', hue = 'genre',data=df3, kind='bar', palette = "Reds", height=8, aspect=1.5)
plt.title("Average Duration by Genre", fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.ylabel('Duration (min)',fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.xlabel('Country', fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.savefig("average_duration2.png")
plt.show()

# %%
maxdur = df2.groupby('country').duration.max()
maxdur
# Out:
# country
# India             224.0
# United Kingdom    208.0
# United States     312.0
# Name: duration, dtype: float64

# %%
dur = pd.DataFrame(data=maxdur).sort_values('duration').reset_index()
dur
# Out:
#           country  duration
# 0  United Kingdom     208.0
# 1           India     224.0
# 2   United States     312.0

# %%
#Country by Duration Bar Chart
plt.figure(figsize=(10,6))
plt.bar(dur.country, dur.duration, color='#E50914', alpha=0.5, align="center")

# Sets the x limits of the current chart
plt.xlim(-0.5, 3)

# Sets the y limits of the current chart
plt.ylim(0, 400)

# Give our chart some labels and a tile
plt.title("Duration by Country", fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.xlabel('Country', fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.ylabel('Duration (min)',fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.savefig("duration_by_country_bar.png")
plt.show()

# %%
#Shortest Movie by Country
plt.figure(figsize=(10,6))
plt.bar(lowest_df.country, lowest_df.duration, color='grey', alpha=0.5, align="center")

# Sets the x limits of the current chart
plt.xlim(-0.5, 3)

# Sets the y limits of the current chart
plt.ylim(0, 400)

# Give our chart some labels and a tile
plt.title("Lowest Movie Duration by Country",fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.xlabel("Country",fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.ylabel("Duration (mins)",fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.savefig("lowest.png")
plt.show()

# %%
usa2 = usa.groupby("genre")
usa2.head()
# Out:
#     show_id                                              title  release_year  \
# 0        s1                               Dick Johnson Is Dead          2020
# 1        s8                                            Sankofa          1993
# 2       s10                                       The Starling          2021
# 4       s28                                          Grown Ups          2010
# 5       s29                                         Dark Skies          2013
# 7       s42                                               Jaws          1975
# 8       s43                                             Jaws 2          1978
# 9       s44                                             Jaws 3          1983
# 10      s45                                  Jaws: The Revenge          1987
# 11      s49                                       Training Day          2001
# 12      s82                                               Kate          2021
# 14      s97  If I Leave Here Tomorrow: A Film About Lynyrd ...          2018
# 15     s102                             Untold: Breaking Point          2021
# 17     s108                                   A Champion Heart          2018
# 25     s128                                 A Cinderella Story          2004
# 26     s132                        Blade Runner: The Final Cut          1982
# 29     s137                                      Cold Mountain          2003
# 30     s139                                          Dear John          2010
# 34     s145                                        House Party          1990
# 35     s146                                      House Party 2          1991
# 36     s147                                      House Party 3          1994
# 47     s168                                      Open Season 2          2008
# 50     s171                                     Rhyme & Reason          1997
# 53     s174                              Snervous Tyler Oakley          2015
# 84     s230                                       The Old Ways          2020
# 85     s232                                      The Water Man          2021
# 99     s308                                          Aftermath          2021
# 103    s326                                          Beethoven          1992
# 125    s354   The Haunting in Connecticut 2: Ghosts of Georgia          2013
# 130    s360                       The Original Kings of Comedy          2000
# 196    s608                                      The Strangers          2008
# 258    s827                                 Bo Burnham: Inside          2021
# 384   s1190       Nate Bargatze: The Greatest Average American          2021
# 386   s1192                                   The Fluffy Movie          2014
# 410   s1279                          Brian Regan: On the Rocks          2021
#
#       type rating        country                     genre  duration
# 0    Movie  PG-13  United States             Documentaries      90.0
# 1    Movie      R  United States                    Dramas     125.0
# 2    Movie  PG-13  United States                  Comedies     104.0
# 4    Movie  PG-13  United States                  Comedies     103.0
# 5    Movie  PG-13  United States             Horror Movies      97.0
# 7    Movie     PG  United States        Action & Adventure     124.0
# 8    Movie     PG  United States                    Dramas     116.0
# 9    Movie     PG  United States        Action & Adventure      98.0
# 10   Movie  PG-13  United States        Action & Adventure      91.0
# 11   Movie      R  United States                    Dramas     122.0
# 12   Movie      R  United States        Action & Adventure     106.0
# 14   Movie      R  United States             Documentaries      97.0
# 15   Movie      R  United States             Documentaries      80.0
# 17   Movie      G  United States  Children & Family Movies      90.0
# 25   Movie     PG  United States  Children & Family Movies      95.0
# 26   Movie      R  United States        Action & Adventure     117.0
# 29   Movie      R  United States                    Dramas     154.0
# 30   Movie  PG-13  United States                    Dramas     108.0
# 34   Movie      R  United States                  Comedies     104.0
# 35   Movie      R  United States                  Comedies      94.0
# 36   Movie      R  United States                  Comedies      94.0
# 47   Movie     PG  United States  Children & Family Movies      76.0
# 50   Movie      R  United States             Documentaries      89.0
# 53   Movie  PG-13  United States             Documentaries      83.0
# 84   Movie      R  United States             Horror Movies      90.0
# 85   Movie     PG  United States  Children & Family Movies      92.0
# 99   Movie      R  United States             Horror Movies     115.0
# 103  Movie     PG  United States  Children & Family Movies      87.0
# 125  Movie      R  United States             Horror Movies     101.0
# 130  Movie      R  United States           Stand-Up Comedy     111.0
# 196  Movie      R  United States             Horror Movies      85.0
# 258  Movie      R  United States           Stand-Up Comedy      88.0
# 384  Movie      G  United States           Stand-Up Comedy      60.0
# 386  Movie  PG-13  United States           Stand-Up Comedy     101.0
# 410  Movie      G  United States           Stand-Up Comedy      58.0

# %%
usa3=usa2.max().reset_index()
usa3
# Out:
#                       genre show_id  \
# 0        Action & Adventure    s971
# 1  Children & Family Movies    s936
# 2                  Comedies    s957
# 3             Documentaries     s97
# 4                    Dramas    s970
# 5             Horror Movies    s963
# 6           Stand-Up Comedy    s827
#
#                                          title  release_year   type rating  \
# 0                                     Æon Flux          2021  Movie      R
# 1                                         Zoom          2021  Movie  PG-13
# 2                                   Zombieland          2021  Movie      R
# 3                                    Woodstock          2021  Movie      R
# 4                                   You Get Me          2021  Movie      R
# 5                             Would You Rather          2021  Movie      R
# 6  Zach Galifianakis: Live at the Purple Onion          2021  Movie      R
#
#          country  duration
# 0  United States     191.0
# 1  United States     139.0
# 2  United States     190.0
# 3  United States     144.0
# 4  United States     312.0
# 5  United States     130.0
# 6  United States     111.0

# %%
#USA Bar Chart
plt.figure(figsize=(10,6))
plt.bar(usa3.genre, usa3.duration, color='#E50914', alpha=0.5, align="center")

# Sets the x limits of the current chart
plt.xlim(-0.5, 7)

# Sets the y limits of the current chart
plt.ylim(0,400)
# Give our chart some labels and a tile
plt.title("USA Movie Duration by Genre",fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.xlabel("Genre",fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.ylabel("Duration (mins)",fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.xticks(rotation=90)
plt.savefig("USA_duration_genre2.png")
plt.show()

# %%
uk2 = uk.groupby("genre")
uk2.head()
# Out:
#      show_id                                     title  release_year   type  \
# 13       s95                                 Show Dogs          2018  Movie
# 19      s116                               Bright Star          2009  Movie
# 21      s118                             Final Account          2021  Movie
# 40      s156                                 Labyrinth          1986  Movie
# 57      s178                      The Guns of Navarone          1961  Movie
# 63      s192                                Wind River          2017  Movie
# 86      s234                               Count Me In          2021  Movie
# 93      s285                       The Kissing Booth 3          2021  Movie
# 95      s293                                   Quartet          2012  Movie
# 98      s305       Lady Boss: The Jackie Collins Story          2021  Movie
# 120     s349                                      Poms          2019  Movie
# 135     s403           The Last Letter From Your Lover          2021  Movie
# 169     s573                                 Hampstead          2019  Movie
# 173     s577                            Mary Magdalene          2019  Movie
# 179     s586                                   Ophelia          2018  Movie
# 283     s915                                    Unrest          2017  Movie
# 292     s933                                Green Zone          2010  Movie
# 293     s934                       Hachi: A Dog's Tale          2009  Movie
# 328    s1034                                      Rush          2013  Movie
# 372    s1148                                Not a Game          2020  Movie
# 385    s1191                                  Skylines          2020  Movie
# 415    s1291                              I Care a Lot          2021  Movie
# 492    s1513      Rhys Nicholson Live at the Athenaeum          2020  Movie
# 527    s1649                             Ghosts of War          2020  Movie
# 572    s1776                                 His House          2020  Movie
# 595    s1860        Octonauts & the Great Barrier Reef          2020  Movie
# 643    s1986              Horrid Henry's Gross Day Out          2020  Movie
# 647    s2001                 Michael McIntyre: Showman          2020  Movie
# 686    s2132        Octonauts & the Caves of Sac Actun          2020  Movie
# 714    s2222           Jack Whitehall: I'm Only Joking          2020  Movie
# 1013   s3158  Jack Whitehall: Christmas with My Father          2019  Movie
# 1110   s3479                     Mo Gilligan: Momentum          2019  Movie
# 1294   s4134                Await Further Instructions          2018  Movie
# 1430   s4511                                   Apostle          2018  Movie
# 1437   s4533                                Malevolent          2018  Movie
#
#      rating         country                     genre  duration
# 13       PG  United Kingdom  Children & Family Movies      90.0
# 19       PG  United Kingdom                    Dramas     119.0
# 21    PG-13  United Kingdom             Documentaries      94.0
# 40       PG  United Kingdom        Action & Adventure     101.0
# 57    PG-13  United Kingdom        Action & Adventure     156.0
# 63        R  United Kingdom                    Dramas     107.0
# 86        R  United Kingdom             Documentaries      82.0
# 93    PG-13  United Kingdom                  Comedies     114.0
# 95    PG-13  United Kingdom                  Comedies      98.0
# 98    PG-13  United Kingdom             Documentaries      97.0
# 120   PG-13  United Kingdom                  Comedies      91.0
# 135       R  United Kingdom                    Dramas     111.0
# 169   PG-13  United Kingdom                  Comedies     103.0
# 173       R  United Kingdom                    Dramas     120.0
# 179   PG-13  United Kingdom                    Dramas     106.0
# 283       R  United Kingdom             Documentaries      97.0
# 292       R  United Kingdom        Action & Adventure     115.0
# 293       G  United Kingdom  Children & Family Movies      93.0
# 328       R  United Kingdom        Action & Adventure     123.0
# 372       R  United Kingdom             Documentaries      98.0
# 385       R  United Kingdom        Action & Adventure     113.0
# 415       R  United Kingdom                  Comedies     118.0
# 492       R  United Kingdom           Stand-Up Comedy      66.0
# 527       R  United Kingdom             Horror Movies      95.0
# 572   PG-13  United Kingdom             Horror Movies      93.0
# 595      PG  United Kingdom  Children & Family Movies      47.0
# 643      PG  United Kingdom  Children & Family Movies      61.0
# 647       R  United Kingdom           Stand-Up Comedy      63.0
# 686      PG  United Kingdom  Children & Family Movies      72.0
# 714       R  United Kingdom           Stand-Up Comedy      58.0
# 1013      R  United Kingdom           Stand-Up Comedy      65.0
# 1110      R  United Kingdom           Stand-Up Comedy      64.0
# 1294      R  United Kingdom             Horror Movies      91.0
# 1430      R  United Kingdom             Horror Movies     130.0
# 1437      R  United Kingdom             Horror Movies      89.0

# %%
uk3=uk2.max().reset_index()
uk3
# Out:
#                       genre show_id                                    title  \
# 0        Action & Adventure    s933                  What Happened to Monday
# 1  Children & Family Movies     s95                             You Can Tutu
# 2                  Comedies   s8734          Wives on Strike: The Revolution
# 3             Documentaries    s915  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# 4                    Dramas    s946                               Wind River
# 5             Horror Movies   s8559                         Under the Shadow
# 6           Stand-Up Comedy   s5860                  Simon Amstell: Set Free
#
#    release_year   type rating         country  duration
# 0          2020  Movie      R  United Kingdom     156.0
# 1          2020  Movie     PG  United Kingdom     146.0
# 2          2021  Movie      R  United Kingdom     137.0
# 3          2021  Movie      R  United Kingdom     208.0
# 4          2021  Movie      R  United Kingdom     163.0
# 5          2020  Movie      R  United Kingdom     130.0
# 6          2020  Movie      R  United Kingdom      94.0

# %%
#UK Bar Chart
plt.figure(figsize=(10,6))
plt.bar(uk3.genre, uk3.duration, color='grey', alpha=0.5, align="center")

# Sets the x limits of the current chart
plt.xlim(-0.5, 7)

# Sets the y limits of the current chart
plt.ylim(0,400)
# Give our chart some labels and a tile
plt.title("UK Movie Duration by Genre",fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.xlabel("Genre",fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.ylabel("Duration (mins)",fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.xticks(rotation=90)
plt.savefig("UK_genre_duration_bar.png")
plt.show()

# %%
india2 = india.groupby("genre")
india2.head()
# Out:
#      show_id                                              title  release_year  \
# 3        s25                                              Jeans          1998
# 16      s106                                   Angamaly Diaries          2017
# 18      s115                                             Anjaam          1994
# 20      s117                                             Dhanak          2015
# 22      s119                                            Gurgaon          2017
# 24      s127                                            Shikara          2020
# 62      s191                                         Thimmarusu          2021
# 64      s193                                         C Kkompany          2008
# 65      s196                    EMI: Liya Hai To Chukana Padega          2008
# 66      s200                                         Koi Aap Sa          2006
# 67      s201                                    Krishna Cottage          2004
# 68      s202                                       Kucch To Hai          2003
# 69      s203                                  Kyaa Kool Hai Hum          2005
# 74      s208          Mission Istaanbul: Darr Ke Aagey Jeet Hai          2008
# 77      s211                                         Ragini MMS          2011
# 78      s212                                       Ragini MMS 2          2014
# 79      s216                            Shootout at Lokhandwala          2007
# 136     s411                 Chhota Bheem And The Broken Amulet          2013
# 137     s416                           Chhota Bheem aur Krishna          2009
# 314     s999                               Searching For Sheela          2021
# 321    s1021                              Madness in the Desert          2004
# 499    s1543         Vir Das: Outside In - The Lockdown Special          2020
# 529    s1654                                        Andhakaaram          2020
# 555    s1703               Fukrey Boyzzz: Space Mein Fukrapanti          2020
# 573    s1778                                        Kaali Khuhi          2020
# 592    s1854                                  Rooting for Roona          2020
# 655    s2021                                                Dhh          2017
# 763    s2343                                            Bulbbul          2020
# 791    s2459  Kenny Sebastian: The Most Interesting Person i...          2020
# 799    s2540                                  Fire in the Blood          2012
# 802    s2545                                     Action Replayy          2010
# 835    s2645                        Yours Sincerely, Kanan Gill          2020
# 921    s2870                     Amit Tandon: Family Tandoncies          2019
# 957    s2988                                 Vir Das: For India          2020
# 1053   s3279                                          SunGanges          2018
#
#        type rating country                     genre  duration
# 3     Movie  PG-13   India                  Comedies     166.0
# 16    Movie  PG-13   India        Action & Adventure     128.0
# 18    Movie  PG-13   India                    Dramas     143.0
# 20    Movie     PG   India                  Comedies     114.0
# 22    Movie  PG-13   India                    Dramas     106.0
# 24    Movie  PG-13   India                    Dramas     115.0
# 62    Movie  PG-13   India                    Dramas     125.0
# 64    Movie  PG-13   India        Action & Adventure     127.0
# 65    Movie  PG-13   India                  Comedies     128.0
# 66    Movie  PG-13   India                  Comedies     135.0
# 67    Movie  PG-13   India        Action & Adventure     124.0
# 68    Movie  PG-13   India                    Dramas     136.0
# 69    Movie      R   India                  Comedies     165.0
# 74    Movie  PG-13   India        Action & Adventure     119.0
# 77    Movie      R   India             Horror Movies      93.0
# 78    Movie      R   India             Horror Movies     113.0
# 79    Movie      R   India        Action & Adventure     116.0
# 136   Movie     PG   India  Children & Family Movies      64.0
# 137   Movie     PG   India  Children & Family Movies      68.0
# 314   Movie  PG-13   India             Documentaries      58.0
# 321   Movie  PG-13   India             Documentaries     141.0
# 499   Movie      R   India           Stand-Up Comedy      50.0
# 529   Movie  PG-13   India             Horror Movies     171.0
# 555   Movie     PG   India  Children & Family Movies      75.0
# 573   Movie  PG-13   India             Horror Movies      91.0
# 592   Movie     PG   India             Documentaries      42.0
# 655   Movie      G   India  Children & Family Movies     127.0
# 763   Movie      R   India             Horror Movies      94.0
# 791   Movie      R   India           Stand-Up Comedy      68.0
# 799   Movie  PG-13   India             Documentaries      83.0
# 802   Movie     PG   India  Children & Family Movies     129.0
# 835   Movie      R   India           Stand-Up Comedy      72.0
# 921   Movie  PG-13   India           Stand-Up Comedy      72.0
# 957   Movie      R   India           Stand-Up Comedy      76.0
# 1053  Movie  PG-13   India             Documentaries      74.0

# %%
india3=india2.max().reset_index()
india3
# Out:
#                       genre show_id                        title  \
# 0        Action & Adventure   s8773                 ​Goli Soda 2
# 1  Children & Family Movies   s8123                     Zokkomon
# 2                  Comedies   s8799     Zindagi Na Milegi Dobara
# 3             Documentaries    s999                     Unbroken
# 4                    Dramas    s975         ​​Kuch Bheege Alfaaz
# 5             Horror Movies   s7872          The House Next Door
# 6           Stand-Up Comedy   s5372  Yours Sincerely, Kanan Gill
#
#    release_year   type rating country  duration
# 0          2020  Movie      R   India     214.0
# 1          2020  Movie  PG-13   India     129.0
# 2          2021  Movie      R   India     203.0
# 3          2021  Movie      R   India     156.0
# 4          2021  Movie      R   India     224.0
# 5          2020  Movie      R   India     171.0
# 6          2020  Movie      R   India      76.0

# %%
#India Bar Chart
plt.figure(figsize=(10,6))
plt.bar(india3.genre, india3.duration, color='black', alpha=0.5, align="center")

# Sets the x limits of the current chart
plt.xlim(-0.5, 7)

# Sets the y limits of the current chart
plt.ylim(0,400)
# Give our chart some labels and a tile
plt.title("India Movie Duration by Genre",fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.xlabel("Genre",fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.ylabel("Duration (mins)",fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.xticks(rotation=90)
plt.savefig("india_duration_genre.png")
plt.show()

# %%
#Top 5 US
usa2 = us_df.head()
usa2
# Out:
#      show_id                                              title  release_year  \
# 1333   s4254                         Black Mirror: Bandersnatch          2018
# 1036   s3228                                       The Irishman          2019
# 3294   s8328                                 The Gospel of Luke          2015
# 3538   s8765                                         Wyatt Earp          1994
# 801    s2544  Unbreakable Kimmy Schmidt: Kimmy vs. the Reverend          2020
#
#        type rating        country               genre  duration
# 1333  Movie      R  United States              Dramas     312.0
# 1036  Movie      R  United States              Dramas     209.0
# 3294  Movie  PG-13  United States              Dramas     205.0
# 3538  Movie  PG-13  United States  Action & Adventure     191.0
# 801   Movie  PG-13  United States            Comedies     190.0

# %%
#Top 5 India
india2 = india_df.head()
india2
# Out:
#      show_id                     title  release_year   type rating country  \
# 320    s1020                    Lagaan          2001  Movie     PG   India
# 1464   s4574              Jodhaa Akbar          2008  Movie  PG-13   India
# 871    s2732  Kabhi Khushi Kabhie Gham          2001  Movie  PG-13   India
# 684    s2127      What's Your Raashee?          2009  Movie     PG   India
# 870    s2731    Kabhi Alvida Naa Kehna          2006  Movie  PG-13   India
#
#                    genre  duration
# 320               Dramas     224.0
# 1464  Action & Adventure     214.0
# 871               Dramas     209.0
# 684             Comedies     203.0
# 870               Dramas     192.0

# %%
#Top 5 UK
uk2 = uk_df.head()
uk2
# Out:
#      show_id                         title  release_year   type rating  \
# 833    s2633  No Direction Home: Bob Dylan          2005  Movie      R
# 2139   s6145                American Honey          2016  Movie      R
# 3293   s8327            The Gospel of John          2014  Movie  PG-13
# 682    s2121                Les Misérables          2012  Movie  PG-13
# 1386   s4432          Dhan Dhana Dhan Goal          2007  Movie  PG-13
#
#              country          genre  duration
# 833   United Kingdom  Documentaries     208.0
# 2139  United Kingdom         Dramas     163.0
# 3293  United Kingdom         Dramas     161.0
# 682   United Kingdom         Dramas     158.0
# 1386  United Kingdom         Dramas     157.0

# %%
#Top 5 Bar Chart
plt.figure(figsize=(10,6))
plt.bar(usa2.title, usa2.duration, color='#E50914', alpha=0.5, align="center")

# Sets the x limits of the current chart
plt.xlim(-0.5, 5)

# Sets the y limits of the current chart
plt.ylim(0,400)
# Give our chart some labels and a tile
plt.title("USA Top 5 Movies",fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.xlabel("Movie",fontname = "Verdana", fontsize=14, fontweight = 'bold')
plt.ylabel("Duration (min)",fontname = "Verdana", fontsize=14, fontweight = 'bold')
plt.xticks(rotation=90)
plt.savefig("top_5_usa2.png")
plt.show()

# %%
#Top 5 UK Bar Chart
plt.figure(figsize=(10,6))
plt.bar(uk2.title, uk2.duration, color='grey', alpha=0.5, align="center")

# Sets the x limits of the current chart
plt.xlim(-0.5, 5)

# Sets the y limits of the current chart
plt.ylim(0,400)
# Give our chart some labels and a tile
plt.title("UK Top 5 Movies",fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.xlabel("Movie",fontname = "Verdana", fontsize=14, fontweight = 'bold')
plt.ylabel("Duration (min)",fontname = "Verdana", fontsize=14, fontweight = 'bold')
plt.xticks(rotation=90)
plt.savefig("uk_top_5.png")
plt.show()

# %%
#Top 5 India Bar Chart
plt.figure(figsize=(10,6))
plt.bar(india2.title, india2.duration, color='black', alpha=0.5, align="center")

# Sets the x limits of the current chart
plt.xlim(-0.5, 5)

# Sets the y limits of the current chart
plt.ylim(0,400)
# Give our chart some labels and a tile
plt.title("India Top 5 Movies",fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.xlabel("Movie",fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.ylabel("Duration (min)",fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.xticks(rotation=90)
plt.savefig("india_top_5.png")
plt.show()

# %%
df4 = df3.head()

# %%
plt.figure(figsize=(10,6))
plt.bar(df4.title, df4.duration, color='#E50914', alpha=0.5, align="center")

# Sets the x limits of the current chart
plt.xlim(-0.5, 5)

# Sets the y limits of the current chart
plt.ylim(0,400)
# Give our chart some labels and a tile
plt.title("Top 5 Movies Overall",fontweight = 'bold', fontname = "Verdana", fontsize=20)
plt.xlabel("Movie",fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.ylabel("Duration (min)",fontname = "Verdana", fontsize=14,fontweight = 'bold')
plt.xticks(rotation=90)
plt.savefig("top_5_overall.png")
plt.show()
