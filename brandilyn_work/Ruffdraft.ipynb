# %%
import pandas as pd
import scipy.stats as stats
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns

# %%
net_movie = pd.read_csv("Resources/netflix_titles.csv")
net_movie
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %%
net_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
net_movie.shape
# Out:
# (8807, 12)

# %%
net_movie.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
net_movie.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
data = pd.read_csv("Resources/netflix_titles.csv")

net_movie = pd.DataFrame(net_movie , columns = ['show_id', 'title', 'release_year', 'duration', 'type', 'country', 'rating', 'listed_in'])

df = net_movie.rename({'listed_in': 'genre'}, axis=1)

df
# Out:
#      show_id                  title  release_year   duration     type  \
# 0         s1   Dick Johnson Is Dead          2020     90 min    Movie
# 1         s2          Blood & Water          2021  2 Seasons  TV Show
# 2         s3              Ganglands          2021   1 Season  TV Show
# 3         s4  Jailbirds New Orleans          2021   1 Season  TV Show
# 4         s5           Kota Factory          2021  2 Seasons  TV Show
# ...      ...                    ...           ...        ...      ...
# 8802   s8803                 Zodiac          2007    158 min    Movie
# 8803   s8804            Zombie Dumb          2018  2 Seasons  TV Show
# 8804   s8805             Zombieland          2009     88 min    Movie
# 8805   s8806                   Zoom          2006     88 min    Movie
# 8806   s8807                 Zubaan          2015    111 min    Movie
#
#             country rating                                              genre
# 0     United States  PG-13                                      Documentaries
# 1      South Africa  TV-MA    International TV Shows, TV Dramas, TV Mysteries
# 2               NaN  TV-MA  Crime TV Shows, International TV Shows, TV Act...
# 3               NaN  TV-MA                             Docuseries, Reality TV
# 4             India  TV-MA  International TV Shows, Romantic TV Shows, TV ...
# ...             ...    ...                                                ...
# 8802  United States      R                     Cult Movies, Dramas, Thrillers
# 8803            NaN  TV-Y7             Kids' TV, Korean TV Shows, TV Comedies
# 8804  United States      R                            Comedies, Horror Movies
# 8805  United States     PG                 Children & Family Movies, Comedies
# 8806          India  TV-14     Dramas, International Movies, Music & Musicals
#
# [8807 rows x 8 columns]

# %%
#df = df.loc[(net_movie["release_year"] > 1990)] 
#df

# %%
df = df.loc[(net_movie["release_year"])]
df
# Out:
#      show_id                              title  release_year   duration  \
# 2020   s2021                                Dhh          2017    127 min
# 2021   s2022                          Greenleaf          2020  5 Seasons
# 2021   s2022                          Greenleaf          2020  5 Seasons
# 2021   s2022                          Greenleaf          2020  5 Seasons
# 2021   s2022                          Greenleaf          2020  5 Seasons
# ...      ...                                ...           ...        ...
# 2007   s2008                         Dad Wanted          2020    103 min
# 2018   s2019  Bhai: Vyakti Ki Valli - Uttarardh          2019    112 min
# 2009   s2010                        Girlfriends          2007  8 Seasons
# 2006   s2007                              Buddi          2020  2 Seasons
# 2015   s2016                        Aapla Manus          2018    133 min
#
#          type                country rating  \
# 2020    Movie                  India   TV-G
# 2021  TV Show          United States  TV-14
# 2021  TV Show          United States  TV-14
# 2021  TV Show          United States  TV-14
# 2021  TV Show          United States  TV-14
# ...       ...                    ...    ...
# 2007    Movie                 Mexico  TV-14
# 2018    Movie                  India  TV-PG
# 2009  TV Show          United States  TV-14
# 2006  TV Show  United Kingdom, China   TV-Y
# 2015    Movie                  India  TV-14
#
#                                                   genre
# 2020  Children & Family Movies, Dramas, Internationa...
# 2021                                          TV Dramas
# 2021                                          TV Dramas
# 2021                                          TV Dramas
# 2021                                          TV Dramas
# ...                                                 ...
# 2007         Children & Family Movies, Comedies, Dramas
# 2018                       Dramas, International Movies
# 2009                                        TV Comedies
# 2006                         British TV Shows, Kids' TV
# 2015            Dramas, International Movies, Thrillers
#
# [8807 rows x 8 columns]

# %% [markdown]
# #Null Value Drops

# %%
df["country_clean"] = [x.split(",")[0] if pd.notnull(x) else x for x in df.country ]
df["genre_clean"] = [x.split(",")[0] if pd.notnull(x) else x for x in df.genre ]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 2020 to 2015
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   show_id        8807 non-null   object
#  1   title          8807 non-null   object
#  2   release_year   8807 non-null   int64
#  3   duration       8807 non-null   object
#  4   type           8807 non-null   object
#  5   country        8329 non-null   object
#  6   rating         8807 non-null   object
#  7   genre          8807 non-null   object
#  8   country_clean  8329 non-null   object
#  9   genre_clean    8807 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 756.9+ KB

# %%
df.country_clean.value_counts()
# Out:
# India             5695
# United States     1170
# United Kingdom     523
# Spain              261
# Germany            203
# France             193
# Mexico              89
# Nigeria             80
# Thailand            39
# Poland              28
# Italy               16
# Japan               14
# Indonesia           13
# South Korea          3
# Egypt                2
# Name: country_clean, dtype: int64

# %%
df.genre_clean.value_counts()
# Out:
# Dramas                      3855
# Children & Family Movies    1555
# Comedies                    1062
# TV Dramas                    599
# British TV Shows             437
# Stand-Up Comedy              412
# International TV Shows       410
# TV Comedies                  154
# Docuseries                    78
# Documentaries                 60
# Action & Adventure            59
# Crime TV Shows                40
# Reality TV                    33
# International Movies          30
# Anime Series                  11
# Kids' TV                      10
# Horror Movies                  2
# Name: genre_clean, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 2020 to 2015
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   show_id        8807 non-null   object
#  1   title          8807 non-null   object
#  2   release_year   8807 non-null   int64
#  3   duration       8807 non-null   object
#  4   type           8807 non-null   object
#  5   country        8329 non-null   object
#  6   rating         8807 non-null   object
#  7   genre          8807 non-null   object
#  8   country_clean  8329 non-null   object
#  9   genre_clean    8807 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 756.9+ KB

# %%
Netclean_df = df[df["type"] != "TV Show"]
Netclean_df.head()
# Out:
#      show_id                              title  release_year duration   type  \
# 2020   s2021                                Dhh          2017  127 min  Movie
# 2020   s2021                                Dhh          2017  127 min  Movie
# 2020   s2021                                Dhh          2017  127 min  Movie
# 2018   s2019  Bhai: Vyakti Ki Valli - Uttarardh          2019  112 min  Movie
# 1996   s1997                      The Paramedic          2020   94 min  Movie
#
#      country rating                                              genre  \
# 2020   India   TV-G  Children & Family Movies, Dramas, Internationa...
# 2020   India   TV-G  Children & Family Movies, Dramas, Internationa...
# 2020   India   TV-G  Children & Family Movies, Dramas, Internationa...
# 2018   India  TV-PG                       Dramas, International Movies
# 1996   Spain  TV-MA            Dramas, International Movies, Thrillers
#
#      country_clean               genre_clean
# 2020         India  Children & Family Movies
# 2020         India  Children & Family Movies
# 2020         India  Children & Family Movies
# 2018         India                    Dramas
# 1996         Spain                    Dramas

# %%
Netclean_df = Netclean_df['duration'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

netclean_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/w1/tsq7fp3s1znc_m2tcd3gpkjm0000gn/T/ipykernel_40233/786653206.py in <module>
# ----> 1 Netclean_df = Netclean_df['duration'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)
#       2
#       3 netclean_df
#       4
#       5
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in unstack(self, level, fill_value)
#    8322         from pandas.core.reshape.reshape import unstack
#    8323
# -> 8324         result = unstack(self, level, fill_value)
#    8325
#    8326         return result.__finalize__(self, method="unstack")
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     445     if isinstance(obj, DataFrame):
#     446         if isinstance(obj.index, MultiIndex):
# --> 447             return _unstack_frame(obj, level, fill_value=fill_value)
#     448         else:
#     449             return obj.T.stack(dropna=False)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/reshape.py in _unstack_frame(obj, level, fill_value)
#     472         return obj._constructor(mgr)
#     473     else:
# --> 474         unstacker = _Unstacker(obj.index, level=level, constructor=obj._constructor)
#     475         return unstacker.get_result(
#     476             obj._values, value_columns=obj.columns, fill_value=fill_value
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/reshape.py in __init__(self, index, level, constructor)
#     131             raise ValueError("Unstacked DataFrame is too big, causing int32 overflow")
#     132
# --> 133         self._make_selectors()
#     134
#     135     @cache_readonly
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/reshape.py in _make_selectors(self)
#     183
#     184         if mask.sum() < len(self.index):
# --> 185             raise ValueError("Index contains duplicate entries, cannot reshape")
#     186
#     187         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
Netclean_df["duration_clean"] = [x.split(" ")[0] if pd.notnull(x) else x for x in df.duration ]
Netclean_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/w1/tsq7fp3s1znc_m2tcd3gpkjm0000gn/T/ipykernel_40233/191422264.py in <module>
# ----> 1 Netclean_df["duration_clean"] = [x.split(" ")[0] if pd.notnull(x) else x for x in df.duration ]
#       2 Netclean_df
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# -> 4509             com.require_length_match(value, self.index)
#    4510         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4511
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/common.py in require_length_match(data, index)
#     529     """
#     530     if len(data) != len(index):
# --> 531         raise ValueError(
#     532             "Length of values "
#     533             f"({len(data)}) "
#
# ValueError: Length of values (8807) does not match length of index (7035)

# %%
df.drop(df.index[df[''] == 'specific_name'], inplace = True)

# %%
#Netclean_df["duration_clean"] = [x.split(" ")[0] if pd.notnull(x) else x for x in df.duration ]
#Netclean_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/w1/tsq7fp3s1znc_m2tcd3gpkjm0000gn/T/ipykernel_40233/1937979858.py in <module>
# ----> 1 Netclean_df["duration_clean"] = [x.split("")[0] if pd.notnull(x) else x for x in df.duration ]
#       2 Netclean_df
#
# /var/folders/w1/tsq7fp3s1znc_m2tcd3gpkjm0000gn/T/ipykernel_40233/1937979858.py in <listcomp>(.0)
# ----> 1 Netclean_df["duration_clean"] = [x.split("")[0] if pd.notnull(x) else x for x in df.duration ]
#       2 Netclean_df
#
# ValueError: empty separator

# %%
df.drop(df.index[df['myvar'] == 'specific_name'], inplace = True)

# %%
Netclean_df = df[df["type"] != "TV Show"]
Netclean_df.head()

# %%
movie = df.groupby(by=['country']).count()
movie

# %%
pandas.DataFrame.groupby
